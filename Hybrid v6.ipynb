# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise.prediction_algorithms import KNNBasic
from surprise import accuracy

#Cargar los datos de los archivos CSVs
jobs_df = pd.read_csv('jobs.csv',sep='\t')
ratings_df = pd.read_csv('ratings_section.csv')
sections_df = pd.read_csv('section.csv')

# Crear todas las combinaciones de secciones y trabajos
all_combinations = pd.MultiIndex.from_product([sections_df['id'], jobs_df['Jobid']], names=['sectionId', 'Jobid'])
all_combinations_df = pd.DataFrame(index=all_combinations).reset_index()

# Unir las combinaciones con los ratings
merged_df = all_combinations_df.merge(ratings_df, on='sectionId', how='left')

# Unir las combinaciones con los nombres de sección
merged_df = merged_df.merge(sections_df, left_on='sectionId', right_on='id', how='left')

# Unir las combinaciones con los datos de los trabajos
merged_df = merged_df.merge(jobs_df, left_on='Jobid', right_on='Jobid', how='left')

# Eliminar filas con valores NaN
merged_df.dropna(subset=['rating'], inplace=True)

#Preparar los datos para Surprise
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(merged_df[['sectionname', 'Description', 'rating']], reader)
trainset, testset = train_test_split(data,test_size=0.2)

#Entrenar el modelo de filtro colaborativo (KNNBasic())
knn_model = KNNBasic()
knn_model.fit(trainset)

#Entrenar el modelo basado en contenido (SVD()):
content_model = SVD()
content_model.fit(trainset)

#Calcular la similitud de descripción de trabajo con los sections y sus ratings:
def calculate_similarity(row):
    sectionname = row['sectionname']
    description = row['Description']
    if sectionname is None or pd.isnull(description):
        return 0
    else:
        rating = row['rating']
        similarity = description.lower().count(sectionname.lower()) * rating
        #print(similarity)
        return similarity


#Realizar predicciones combinando los modelos:
predictions = []
max_rating = merged_df['rating'].max()
min_rating = merged_df['rating'].min()

for test_section, test_description, test_rating in testset:
    knn_pred = knn_model.predict(test_section, test_description, test_rating).est
    content_pred = content_model.predict(test_section, test_description, test_rating).est

    similarity_pred_content = calculate_similarity({'sectionname': test_section, 'Description': test_description, 'rating': content_pred})
    similarity_pred_knn = calculate_similarity({'sectionname': test_section, 'Description': test_description, 'rating': knn_pred})

    similarity_hybrid_pred = min((similarity_pred_content + similarity_pred_knn) / 2, 1.0)
    similarity_hybrid_pred = round(similarity_hybrid_pred, 1)

    # Ajustar similarity_hybrid_pred en función del rating de la sección
    section_rating = merged_df.loc[merged_df['sectionname'] == test_section, 'rating'].iloc[0]
    normalized_rating = (section_rating - min_rating) / (max_rating - min_rating)

    similarity_hybrid_pred *= normalized_rating

    predictions.append((test_section, test_description, test_rating, similarity_hybrid_pred))


df_predictions = pd.DataFrame(predictions, columns=['sectionname', 'Description', 'rating','similarity_pred'])

recommendations = merged_df[['Jobid', 'Jobname', 'URL', 'Location', 'Date', 'Company','Description']].merge(df_predictions, on='Description')
recommendations = recommendations.sort_values('similarity_pred', ascending=False)[['Jobname', 'URL', 'Location','Date', 'Company', 'similarity_pred']]
recommendations = recommendations.drop_duplicates(subset=['Jobname'])
print(recommendations)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
#                                                 Jobname  \
# 0                          FullStack Developer (Remote)
# 1741                      Especialista de Base de Datos
# 2537  React.js/TypeScript Developer - Remote - Latin...
# 346   Programador / Desarrollador Fullstack Jr. / TI...
# 337   Programador / Desarrollador Fullstack Junior -...
# 768       Analista Desarrollador de Backend- San Isidro
# 1505                         Desarrollador Java Backend
# 2716  PHP + Laravel + Vue.js/React.js Developer - Re...
# 1127                                  Developer Backend
# 2841                  FullStack Developer Netcore React
# 2169                     Desarrollador Front End (Lima)
# 1533            Analista Programador .Net Core/ Angular
# 1169                                Fullstack developer
# 3418                                      iOS Developer
# 2580  Full Stack React.js Developer - Remote - Latin...
# 2417                         Desarrollador de front-end
# 2667                   Fullstack Python/React Developer
# 2364                     Analista Programador Front End
# 2370                           Desarrollador Web Python
# 2347       Praticante de Desarrollador Web - Ad Honorem
# 2500          React Software Developer - Work from home
# 2460  Diseñador Web - Estrategia Digital (Condor Tra...
# 2245                        Front-end Software Engineer
# 2058                               Programador Frontend
# 2048                 Analista de Control Medios de Pago
# 2109  Junior Frontend Developer (Remote Internship –...
# 1957               Analista gobierno de datos - Hibrido
# 2276  Programador Front End con experiencia - Mirafl...
# 2280                                 Frontend Developer
# 2804                            Desarrollador de Python
# 3254          Desarrollador Backend TypeScript - Nodejs
# 3113                       Desarrollador Android Kotlin
# 3315           Analista Programador Móvil (Android/iOS)
# 3151                                Desarrollador movil
# 3476             SENIOR BACK-END DEVELOPER - Dubai, UAE
# 3480                           Native Android Developer
# 3358              Back End Developer {Java -Springboot}
# 2850                         Java Fullstack (en España)
# 3048                       Mobile Developer Semi Senior
# 3038                                     Fullstack .Net
# 3010          Golang Developer - Remote - Latin America
# 741                     Analista Programador Full Stack
# 716                                      JAVA DEVELOPER
# 830                               Desarrollador Backend
# 640                                   Backend Developer
# 615                              Programador Full Stack
# 969                           Desarrollador de back-end
# 870                                      Java Developer
# 55                                 Full-Stack Developer
# 1637                      Analista de Gestión Comercial
# 1650  Practicante de Gestión de Información y Proyectos
# 1695  Analista de Datos e Innovación / Analista de ...
# 1109                                Fullstack Developer
#
#                                                     URL  \
# 0     https://pe.linkedin.com/jobs/view/fullstack-de...
# 1741  https://pe.linkedin.com/jobs/view/especialista...
# 2537  https://pe.linkedin.com/jobs/view/react-js-typ...
# 346   https://pe.linkedin.com/jobs/view/programador-...
# 337   https://pe.linkedin.com/jobs/view/programador-...
# 768   https://pe.linkedin.com/jobs/view/analista-des...
# 1505  https://pe.linkedin.com/jobs/view/desarrollado...
# 2716  https://pe.linkedin.com/jobs/view/php-%2B-lara...
# 1127  https://pe.linkedin.com/jobs/view/developer-ba...
# 2841  https://pe.linkedin.com/jobs/view/fullstack-de...
# 2169  https://pe.linkedin.com/jobs/view/desarrollado...
# 1533  https://pe.linkedin.com/jobs/view/analista-pro...
# 1169  https://pe.linkedin.com/jobs/view/fullstack-de...
# 3418  https://pe.linkedin.com/jobs/view/ios-develope...
# 2580  https://pe.linkedin.com/jobs/view/full-stack-r...
# 2417  https://pe.linkedin.com/jobs/view/desarrollado...
# 2667  https://pe.linkedin.com/jobs/view/fullstack-py...
# 2364  https://pe.linkedin.com/jobs/view/analista-pro...
# 2370  https://pe.linkedin.com/jobs/view/desarrollado...
# 2347  https://pe.linkedin.com/jobs/view/praticante-d...
# 2500  https://pe.linkedin.com/jobs/view/react-softwa...
# 2460  https://pe.linkedin.com/jobs/view/dise%C3%B1ad...
# 2245  https://pe.linkedin.com/jobs/view/front-end-so...
# 2058  https://pe.linkedin.com/jobs/view/programador-...
# 2048  https://pe.linkedin.com/jobs/view/analista-de-...
# 2109  https://pe.linkedin.com/jobs/view/junior-front...
# 1957  https://pe.linkedin.com/jobs/view/analista-gob...
# 2276  https://pe.linkedin.com/jobs/view/programador-...
# 2280  https://pe.linkedin.com/jobs/view/frontend-dev...
# 2804  https://pe.linkedin.com/jobs/view/desarrollado...
# 3254  https://pe.linkedin.com/jobs/view/desarrollado...
# 3113  https://pe.linkedin.com/jobs/view/desarrollado...
# 3315  https://pe.linkedin.com/jobs/view/analista-pro...
# 3151  https://pe.linkedin.com/jobs/view/desarrollado...
# 3476  https://pe.linkedin.com/jobs/view/senior-back-...
# 3480  https://pe.linkedin.com/jobs/view/native-andro...
# 3358  https://pe.linkedin.com/jobs/view/back-end-dev...
# 2850  https://pe.linkedin.com/jobs/view/java-fullsta...
# 3048  https://pe.linkedin.com/jobs/view/mobile-devel...
# 3038  https://pe.linkedin.com/jobs/view/fullstack-ne...
# 3010  https://pe.linkedin.com/jobs/view/golang-devel...
# 741   https://pe.linkedin.com/jobs/view/analista-pro...
# 716   https://pe.linkedin.com/jobs/view/java-develop...
# 830   https://pe.linkedin.com/jobs/view/desarrollado...
# 640   https://pe.linkedin.com/jobs/view/backend-deve...
# 615   https://pe.linkedin.com/jobs/view/programador-...
# 969   https://pe.linkedin.com/jobs/view/desarrollado...
# 870   https://pe.linkedin.com/jobs/view/java-develop...
# 55    https://pe.linkedin.com/jobs/view/full-stack-d...
# 1637  https://pe.linkedin.com/jobs/view/analista-de-...
# 1650  https://pe.linkedin.com/jobs/view/practicante-...
# 1695  https://pe.linkedin.com/jobs/view/analista-de-...
# 1109  https://pe.linkedin.com/jobs/view/fullstack-de...
#
#                            Location          Date  \
# 0                  Lima, Lima, Peru    1 week ago
# 1741               Lima, Lima, Peru    5 days ago
# 2537               Lima, Lima, Peru    5 days ago
# 346                 Ate, Lima, Peru   2 weeks ago
# 337                 Ate, Lima, Peru    1 week ago
# 768          San Isidro, Lima, Peru   3 weeks ago
# 1505                     Lima, Peru   3 weeks ago
# 2716               Lima, Lima, Peru    1 week ago
# 1127                     Lima, Peru   2 weeks ago
# 2841         San Isidro, Lima, Peru    1 week ago
# 2169               Lima, Lima, Peru    1 week ago
# 1533          San Borja, Lima, Peru    5 days ago
# 1169         Miraflores, Lima, Peru    4 days ago
# 3418               Lima, Lima, Peru     1 day ago
# 2580               Lima, Lima, Peru    1 week ago
# 2417                     Lima, Peru   9 hours ago
# 2667               Lima, Lima, Peru     1 day ago
# 2364          San Borja, Lima, Peru   4 weeks ago
# 2370               Lima, Lima, Peru   2 hours ago
# 2347               Lima, Lima, Peru   2 weeks ago
# 2500                     Lima, Peru   8 hours ago
# 2460               Lima, Lima, Peru   4 weeks ago
# 2245               Lima, Lima, Peru    5 days ago
# 2058               Lima, Lima, Peru   2 weeks ago
# 2048         San Isidro, Lima, Peru   2 weeks ago
# 2109               Lima, Lima, Peru    6 days ago
# 1957               Lima, Lima, Peru    5 days ago
# 2276               Lima, Lima, Peru    1 hour ago
# 2280                     Lima, Peru   3 hours ago
# 2804         Miraflores, Lima, Peru   7 hours ago
# 3254               Lima, Lima, Peru    4 days ago
# 3113               Lima, Lima, Peru   3 weeks ago
# 3315                     Lima, Peru   3 weeks ago
# 3151        La Victoria, Lima, Peru   2 weeks ago
# 3476               Lima, Lima, Peru    5 days ago
# 3480               Lima, Lima, Peru     1 day ago
# 3358                     Lima, Peru     1 day ago
# 2850                     Lima, Peru    1 week ago
# 3048               Lima, Lima, Peru     1 day ago
# 3038         Miraflores, Lima, Peru  14 hours ago
# 3010               Lima, Lima, Peru   2 weeks ago
# 741                Lima, Lima, Peru     1 day ago
# 716                Lima, Lima, Peru   2 weeks ago
# 830                      Lima, Peru   2 weeks ago
# 640                      Lima, Peru   4 hours ago
# 615                Lima, Lima, Peru    1 week ago
# 969                      Lima, Peru   2 weeks ago
# 870                Lima, Lima, Peru   2 weeks ago
# 55                 Lima, Lima, Peru    3 days ago
# 1637         San Isidro, Lima, Peru   2 weeks ago
# 1650         San Isidro, Lima, Peru   2 weeks ago
# 1695  Santiago de Surco, Lima, Peru   2 weeks ago
# 1109               Lima, Lima, Peru    1 week ago
#
#                            Company  similarity_pred
# 0                             Atom              1.0
# 1741                        izipay              1.0
# 2537                FullStack Labs              1.0
# 346                       TRBA SAC              1.0
# 337                       TRBA SAC              1.0
# 768                   Los Portales              1.0
# 1505     Tata Consultancy Services              1.0
# 2716                FullStack Labs              1.0
# 1127     Tata Consultancy Services              1.0
# 2841                       TiSmart              0.6
# 2169                     Perú Rail              0.6
# 1533            Efitec-Corporation              0.6
# 1169                    PLAY Group              0.5
# 3418                    Clevertech              0.4
# 2580                FullStack Labs              0.0
# 2417     Tata Consultancy Services              0.0
# 2667                    Clevertech              0.0
# 2364                         Valtx              0.0
# 2370                          Aimo              0.0
# 2347                     AbecexCom              0.0
# 2500                       Oowlish              0.0
# 2460               Expertia Travel              0.0
# 2245                IDM Technology              0.0
# 2058           CEPAL INTERNATIONAL              0.0
# 2048                    Scotiabank              0.0
# 2109     TalentKompass Deutschland              0.0
# 1957                       Vooxell              0.0
# 2276  Soluciones Empresariales GJG              0.0
# 2280                        Inetum              0.0
# 2804                AYNITECH GROUP              0.0
# 3254                     CSTI Corp              0.0
# 3113                     CSTI Corp              0.0
# 3315                        SOAINT              0.0
# 3151     Fonbienes Peru EAFC S.A..              0.0
# 3476            Cobblestone Energy              0.0
# 3480                    Clevertech              0.0
# 3358                      Global66              0.0
# 2850                         Anywr              0.0
# 3048                  BBVA en Perú              0.0
# 3038                         Tsoft              0.0
# 3010                FullStack Labs              0.0
# 741                 BIGDAVI S.A.C.              0.0
# 716                  DPC Asociados              0.0
# 830      Tata Consultancy Services              0.0
# 640                         SOAINT              0.0
# 615                           CTIC              0.0
# 969      Tata Consultancy Services              0.0
# 870                 AYNITECH GROUP              0.0
# 55               Rivka Development              0.0
# 1637                    Scotiabank              0.0
# 1650              Pacífico Seguros              0.0
# 1695                 Apuesta Total              0.0
# 1109                           SAP              0.0
